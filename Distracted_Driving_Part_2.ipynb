# %% [markdown]
# <a href="https://colab.research.google.com/github/adnanq2004/distracted_driving/blob/main/Distracted_Driving_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![](http://static1.squarespace.com/static/56ccc8724c2f8548059fbcfe/58f6daea15d5dbcc64ef63aa/5cae2d770d92977242838baa/1557942174418/SW-DistractedDriving-Clean-1.jpg?format=1500w)

# %%
#@title Run this to download data and prepare our environment! { display-mode: "form" }


import cv2
import numpy as np

def label_to_numpy(labels):
  final_labels = np.zeros((len(labels), 4))
  for i in range(len(labels)):
    label = labels[i]
    if label == 'Attentive':
      final_labels[i,:] = np.array([1, 0, 0, 0])
    if label == 'DrinkingCoffee':
      final_labels[i,:] = np.array([0, 1, 0, 0])
    if label == 'UsingMirror':
      final_labels[i,:] = np.array([0, 0, 1, 0])
    if label == 'UsingRadio':
      final_labels[i,:] = np.array([0, 0, 0, 1])
  return final_labels

def augment(data, augmenter):
  if len(data.shape) == 3:
    return augmenter.augment_image(data)
  if len(data.shape) == 4:
    return augmenter.augment_images(data)
    
def rotate(data, rotate):
  fun = augmenters.Affine(rotate = rotate)
  return augment(data, fun)

def shear(data, shear):
  fun = augmenters.Affine(shear = shear)
  return augment(data, fun)

def scale(data, scale):
  fun = augmenters.Affine(scale = shear)
  return augment(data, fun)
  
def flip_left_right(data):
  fun = augmenters.Fliplr()
  return augment(data, fun)

def flip_up_down(data):
  fun = augmenters.Flipud()
  return augment(data, fun)

def remove_color(data, channel):
  new_data = data.copy()
  if len(data.shape) == 3:
    new_data[:,:,channel] = 0
    return new_data
  if len(data.shape) == 4:
    new_data[:,:,:,channel] = 0
    return new_data
  
class pkg:
  #### DOWNLOADING AND LOADING DATA
  def get_metadata(metadata_path, which_splits = ['train', 'test']):  
    '''returns metadata dataframe which contains columns of:
       * index: index of data into numpy data
       * class: class of image
       * split: which dataset split is this a part of? 
    '''
    metadata = pd.read_csv(metadata_path)
    keep_idx = metadata['split'].isin(which_splits)
    metadata = metadata[keep_idx]
    
    # Get dataframes for each class.
    df_coffee_train = metadata[(metadata['class'] == 'DrinkingCoffee') & \
                         (metadata['split'] == 'train')]
    df_coffee_test = metadata[(metadata['class'] == 'DrinkingCoffee') & \
                         (metadata['split'] == 'test')]
    df_mirror_train = metadata[(metadata['class'] == 'UsingMirror') & \
                         (metadata['split'] == 'train')]
    df_mirror_test = metadata[(metadata['class'] == 'UsingMirror') & \
                         (metadata['split'] == 'test')]
    df_attentive_train = metadata[(metadata['class'] == 'Attentive') & \
                         (metadata['split'] == 'train')]
    df_attentive_test = metadata[(metadata['class'] == 'Attentive') & \
                         (metadata['split'] == 'test')]
    df_radio_train = metadata[(metadata['class'] == 'UsingRadio') & \
                         (metadata['split'] == 'train')]
    df_radio_test = metadata[(metadata['class'] == 'UsingRadio') & \
                         (metadata['split'] == 'test')]

    # Get number of items in class with lowest number of images.
    num_samples_train = min(df_coffee_train.shape[0], \
                            df_mirror_train.shape[0], \
                            df_attentive_train.shape[0], \
                            df_radio_train.shape[0])
    num_samples_test = min(df_coffee_test.shape[0], \
                            df_mirror_test.shape[0], \
                            df_attentive_test.shape[0], \
                            df_radio_test.shape[0])

    # Resample each of the classes and concatenate the images.
    metadata_train = pd.concat([df_coffee_train.sample(num_samples_train), \
                          df_mirror_train.sample(num_samples_train), \
                          df_attentive_train.sample(num_samples_train), \
                          df_radio_train.sample(num_samples_train) ])
    metadata_test = pd.concat([df_coffee_test.sample(num_samples_test), \
                          df_mirror_test.sample(num_samples_test), \
                          df_attentive_test.sample(num_samples_test), \
                          df_radio_test.sample(num_samples_test) ])
    
    metadata = pd.concat( [metadata_train, metadata_test] )
    
    return metadata

  def get_data_split(split_name, flatten, all_data, metadata, image_shape):
    '''
    returns images (data), labels from folder of format [image_folder]/[split_name]/[class_name]/
    flattens if flatten option is True 
    '''
    # Get dataframes for each class.
    df_coffee_train = metadata[(metadata['class'] == 'DrinkingCoffee') & \
                         (metadata['split'] == 'train')]
    df_coffee_test = metadata[(metadata['class'] == 'DrinkingCoffee') & \
                         (metadata['split'] == 'test')]
    df_mirror_train = metadata[(metadata['class'] == 'UsingMirror') & \
                         (metadata['split'] == 'train')]
    df_mirror_test = metadata[(metadata['class'] == 'UsingMirror') & \
                         (metadata['split'] == 'test')]
    df_attentive_train = metadata[(metadata['class'] == 'Attentive') & \
                         (metadata['split'] == 'train')]
    df_attentive_test = metadata[(metadata['class'] == 'Attentive') & \
                         (metadata['split'] == 'test')]
    df_radio_train = metadata[(metadata['class'] == 'UsingRadio') & \
                         (metadata['split'] == 'train')]
    df_radio_test = metadata[(metadata['class'] == 'UsingRadio') & \
                         (metadata['split'] == 'test')]

    # Get number of items in class with lowest number of images.
    num_samples_train = min(df_coffee_train.shape[0], \
                            df_mirror_train.shape[0], \
                            df_attentive_train.shape[0], \
                            df_radio_train.shape[0])
    num_samples_test = min(df_coffee_test.shape[0], \
                            df_mirror_test.shape[0], \
                            df_attentive_test.shape[0], \
                            df_radio_test.shape[0])

    # Resample each of the classes and concatenate the images.
    metadata_train = pd.concat([df_coffee_train.sample(num_samples_train), \
                          df_mirror_train.sample(num_samples_train), \
                          df_attentive_train.sample(num_samples_train), \
                          df_radio_train.sample(num_samples_train) ])
    metadata_test = pd.concat([df_coffee_test.sample(num_samples_test), \
                          df_mirror_test.sample(num_samples_test), \
                          df_attentive_test.sample(num_samples_test), \
                          df_radio_test.sample(num_samples_test) ])
    
    metadata = pd.concat( [metadata_train, metadata_test] )
    
    sub_df = metadata[metadata['split'].isin([split_name])]
    index  = sub_df['index'].values
    labels = sub_df['class'].values
    data = all_data[index,:]
    if flatten:
      data = data.reshape([-1, np.product(image_shape)])
    return data, labels

  def get_train_data(flatten, all_data, metadata, image_shape):
    return get_data_split('train', flatten, all_data, metadata, image_shape)

  def get_test_data(flatten, all_data, metadata, image_shape):
    return get_data_split('test', flatten, all_data, metadata, image_shape)

  def get_field_data(flatten, all_data, metadata, image_shape):
    return get_data_split('field', flatten, all_data, metadata, image_shape)
  
class helpers:
  #### PLOTTING
  def plot_image(data, num_ims, figsize=(8,6), labels = [], index = None, image_shape = [64,64,3]):
    '''
    if data is a single image, display that image

    if data is a 4d stack of images, display that image
    '''
    print(data.shape)
    num_dims   = len(data.shape)
    num_labels = len(labels)

    # reshape data if necessary
    if num_dims == 1:
      data = data.reshape(target_shape)
    if num_dims == 2:
      data = data.reshape(-1,image_shape[0],image_shape[1],image_shape[2])
    num_dims   = len(data.shape)

    # check if single or multiple images
    if num_dims == 3:
      if num_labels > 1:
        print('Multiple labels does not make sense for single image.')
        return

      label = labels      
      if num_labels == 0:
        label = ''
      image = data

    if num_dims == 4:
      image = data[index, :]
      label = labels[index]

    # plot image of interest
    
    nrows=int(np.sqrt(num_ims))
    ncols=int(np.ceil(num_ims/nrows))
    print(nrows,ncols)
    count=0
    if nrows==1 and ncols==1:
      print('Label: %s'%label)
      plt.imshow(image)
      plt.show()
    else:
      print(labels)
      fig = plt.figure(figsize=figsize)
      for i in range(nrows):
        for j in range(ncols):
          if count<num_ims:
            fig.add_subplot(nrows,ncols,count+1)
            plt.imshow(image[count])
            count+=1
      fig.set_size_inches(18.5, 10.5)
      plt.show()

    

  #### QUERYING AND COMBINING DATA
  def get_misclassified_data(data, labels, predictions):
    '''
    Gets the data and labels that are misclassified in a classification task
    Returns:
    -missed_data
    -missed_labels
    -predicted_labels (corresponding to missed_labels)
    -missed_index (indices of items in original dataset)
    '''
    missed_index     = np.where(np.abs(predictions.squeeze() - labels.squeeze()) > 0)[0]
    missed_labels    = labels[missed_index]
    missed_data      = data[missed_index,:]
    predicted_labels = predictions[missed_index]
    return missed_data, missed_labels, predicted_labels, missed_index

  def combine_data(data_list, labels_list):
    return np.concatenate(data_list, axis = 0), np.concatenate(labels_list, axis = 0)

  def model_to_string(model):
    import re
    stringlist = []
    model.summary(print_fn=lambda x: stringlist.append(x))
    sms = "\n".join(stringlist)
    sms = re.sub('_\d\d\d','', sms)
    sms = re.sub('_\d\d','', sms)
    sms = re.sub('_\d','', sms)  
    return sms

  def plot_acc(history, ax = None, xlabel = 'Epoch #'):
    # i'm sorry for this function's code. i am so sorry. 
    history = history.history
    history.update({'epoch':list(range(len(history['val_accuracy'])))})
    history = pd.DataFrame.from_dict(history)

    best_epoch = history.sort_values(by = 'val_accuracy', ascending = False).iloc[0]['epoch']

    if not ax:
      f, ax = plt.subplots(1,1)
    sns.lineplot(x = 'epoch', y = 'val_accuracy', data = history, label = 'Validation', ax = ax)
    sns.lineplot(x = 'epoch', y = 'accuracy', data = history, label = 'Training', ax = ax)
    ax.axhline(0.25, linestyle = '--',color='red', label = 'Chance')
    ax.axvline(x = best_epoch, linestyle = '--', color = 'green', label = 'Best Epoch')  
    ax.legend(loc = 1)    
    ax.set_ylim([0.01, 1])

    ax.set_xlabel(xlabel)
    ax.set_ylabel('Accuracy (Fraction)')
    
    plt.show()

class models:
  def DenseClassifier(hidden_layer_sizes, nn_params, dropout = 0.5):
    model = Sequential()
    model.add(Flatten(input_shape = nn_params['input_shape']))
    for ilayer in hidden_layer_sizes:
      model.add(Dense(ilayer, activation = 'relu'))
      if dropout:
        model.add(Dropout(dropout))
    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))
    model.compile(loss=nn_params['loss'],
                  optimizer=optimizers.SGD(lr=1e-4, momentum=0.95),
                  metrics=['accuracy'])
    return model

  def CNNClassifier(num_hidden_layers, nn_params, dropout = 0.5):
    model = Sequential()

    model.add(Conv2D(32, (3, 3), input_shape=nn_params['input_shape'], padding = 'same'))
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))

    for i in range(num_hidden_layers-1):
        model.add(Conv2D(32, (3, 3), padding = 'same'))
        model.add(Activation('relu'))
        model.add(MaxPooling2D(pool_size=(2, 2)))

    model.add(Flatten()) 

    model.add(Dense(units = 128, activation = 'relu'))
    model.add(Dropout(dropout))

    model.add(Dense(units = 64, activation = 'relu'))


    model.add(Dense(units = nn_params['output_neurons'], activation = nn_params['output_activation']))

    # initiate RMSprop optimizer
    opt = tensorflow.keras.optimizers.RMSprop(lr=1e-4)

    # Let's train the model using RMSprop
    model.compile(loss=nn_params['loss'],
                  optimizer=opt,
                  metrics=['accuracy'])    
    return model

  def TransferClassifier(name, nn_params, trainable = True):
    expert_dict = {'VGG16': VGG16, 
                   'VGG19': VGG19,
                   'ResNet50':ResNet50,
                   'DenseNet121':DenseNet121}

    expert_conv = expert_dict[name](weights = 'imagenet', 
                                              include_top = False, 
                                              input_shape = nn_params['input_shape'])
    for layer in expert_conv.layers:
      layer.trainable = trainable
      
    expert_model = Sequential()
    expert_model.add(expert_conv)
    expert_model.add(GlobalAveragePooling2D())

    expert_model.add(Dense(128, activation = 'relu'))
    expert_model.add(Dropout(0.3))

    expert_model.add(Dense(64, activation = 'relu'))

    expert_model.add(Dense(nn_params['output_neurons'], activation = nn_params['output_activation']))

    expert_model.compile(loss = nn_params['loss'], 
                  optimizer = optimizers.SGD(lr=1e-4, momentum=0.95), 
                  metrics=['accuracy'])

    return expert_model

import gdown
import zipfile

import os
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn import model_selection

from collections import Counter

import tensorflow.keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, MaxPooling2D, Dropout, Flatten, Reshape, Dense, Conv2D, GlobalAveragePooling2D
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
import tensorflow.keras.optimizers as optimizers
from tensorflow.keras.callbacks import ModelCheckpoint

from tensorflow.keras.applications import VGG16, VGG19, ResNet50, DenseNet121

from imgaug import augmenters 

### defining project variables
# file variables
# image_data_url       = 'https://drive.google.com/uc?id=1qmTuUyn0525-612yS-wkp8gHB72Wv_XP'
# metadata_url         = 'https://drive.google.com/uc?id=1OfKnq3uIT29sXjWSZqOOpceig8Ul24OW'
image_data_path      = './image_data.npy'
metadata_path        = './metadata.csv'
image_shape          = (64, 64, 3)

# neural net parameters
nn_params = {}
nn_params['input_shape']       = image_shape
nn_params['output_neurons']    = 4
nn_params['loss']              = 'categorical_crossentropy'
nn_params['output_activation'] = 'softmax'

### Download data
# !wget -O metadata.csv 'https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20Driver%20Distraction%20Detection/metadata%20(1).csv'
# !wget -O image_data.npy 'https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20Driver%20Distraction%20Detection/image_data%20(1).npy'
# gdown.download(image_data_url, image_data_path , True)
# gdown.download(metadata_url, metadata_path , True)


### pre-loading all data of interest
_all_data = np.load('image_data.npy')
_metadata = pkg.get_metadata(metadata_path, ['train','test','field'])

### preparing definitions
# downloading and loading data
get_data_split = pkg.get_data_split
get_metadata    = lambda :                 pkg.get_metadata(metadata_path, ['train','test'])
get_train_data  = lambda flatten = False : pkg.get_train_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_test_data   = lambda flatten = False : pkg.get_test_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)
get_field_data  = lambda flatten = False : pkg.get_field_data(flatten = flatten, all_data = _all_data, metadata = _metadata, image_shape = image_shape)

# plotting
plot_image = lambda data, num_ims,figsize=(8,6), labels = [], index = None: helpers.plot_image(data = data, num_ims=num_ims, figsize=figsize,labels = labels, index = index, image_shape = image_shape);
plot_acc       = lambda history: helpers.plot_acc(history)

# querying and combining data
model_to_string        = lambda model: helpers.model_to_string(model)
get_misclassified_data = helpers.get_misclassified_data;
combine_data           = helpers.combine_data;

# models with input parameters
DenseClassifier     = lambda hidden_layer_sizes: models.DenseClassifier(hidden_layer_sizes = hidden_layer_sizes, nn_params = nn_params);
CNNClassifier       = lambda num_hidden_layers: models.CNNClassifier(num_hidden_layers, nn_params = nn_params);
TransferClassifier  = lambda name: models.TransferClassifier(name = name, nn_params = nn_params);

monitor = ModelCheckpoint('./model.h5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')
# Out:
# --2022-01-02 15:44:27--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20Driver%20Distraction%20Detection/metadata%20(1).csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 108.177.112.128, 74.125.124.128, 172.217.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|108.177.112.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 205142 (200K) [text/csv]
# Saving to: ‘metadata.csv’
#
# metadata.csv        100%[===================>] 200.33K  --.-KB/s    in 0.003s
#
# 2022-01-02 15:44:27 (60.2 MB/s) - ‘metadata.csv’ saved [205142/205142]
#
# --2022-01-02 15:44:27--  https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%206%20-%2010%20(Projects)/Project%20-%20Driver%20Distraction%20Detection/image_data%20(1).npy
# Resolving storage.googleapis.com (storage.googleapis.com)... 172.217.214.128, 172.253.119.128, 108.177.111.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|172.217.214.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 444186752 (424M) [application/octet-stream]
# Saving to: ‘image_data.npy’
#
# image_data.npy      100%[===================>] 423.61M   106MB/s    in 3.9s
#
# 2022-01-02 15:44:31 (108 MB/s) - ‘image_data.npy’ saved [444186752/444186752]

# %%
# grab tools from our tensorflow and keras toolboxes!
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras import optimizers

# %%
# create our model by specifying and compiling it
model = Sequential()
model.add(Dense(4, input_shape=(3,),activation = 'relu'))
model.add(Dense(1, activation = 'linear'))
model.compile(loss='mean_squared_error',
                optimizer='adam',
                metrics=['mean_squared_error'])

# %%
# grab tools from our tensorflow and keras toolboxes!
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras import optimizers

# %%
model_1 = Sequential()
model_1.add(Dense(4, input_shape=(3,),activation = 'relu'))
model_1.add(Dense(2, activation = 'softmax'))
model_1.compile(loss='categorical_crossentropy',
              optimizer = 'adam',
              metrics = ['accuracy'])

# %%
model = Sequential()

model.add(Flatten(input_shape=(64,64,3))) 
model.add(Dense(128, activation = 'relu'))
model.add(Dense(4,activation = 'softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer = optimizers.SGD(learning_rate=1e-4, momentum=0.95),
              metrics = ['accuracy'])

# %%
#@title Run this to test if your model is right! { display-mode: "form" }
perceptron_answer = Sequential()
perceptron_answer.add(Flatten(input_shape = (64, 64, 3)))
perceptron_answer.add(Dense(units = 128, activation = 'relu'))
perceptron_answer.add(Dense(units = 4, activation = 'sigmoid'))
    
perceptron_answer.compile(loss='categorical_crossentropy',
              optimizer=optimizers.SGD(learning_rate=1e-4, momentum=0.95),
              metrics=['accuracy'])

if model_to_string(model) == model_to_string(perceptron_answer):
  print('Good job, you specified it correctly!')
else: 
  print('Please check your code again!')
# Out:
# Please check your code again!

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
# define our monitor. Don't worry about the parameters here except for './model.h5' which is the file that our model saves to 
monitor = ModelCheckpoint('./model.h5', monitor='val_loss', verbose=0, save_best_only=True, save_weights_only=False, mode='auto', save_freq='epoch')

train_data, train_labels = get_train_data()
test_data, test_labels = get_test_data()

# Reshape the data.
train_data = train_data.reshape([-1, 64, 64, 3])
test_data = test_data.reshape([-1, 64, 64, 3])

# Convert string labels into numpy arrays.
train_labels = label_to_numpy(train_labels)
test_labels = label_to_numpy(test_labels)

history = model.fit(train_data, train_labels, epochs = 50, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
plot_acc(history)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 5s 13ms/step - loss: 1.1080 - accuracy: 0.5809 - val_loss: 1.3440 - val_accuracy: 0.4022
# Epoch 2/50
# 211/211 [==============================] - 1s 7ms/step - loss: 0.6791 - accuracy: 0.8627 - val_loss: 1.6022 - val_accuracy: 0.3413
# Epoch 3/50
# 211/211 [==============================] - 2s 8ms/step - loss: 0.4728 - accuracy: 0.9291 - val_loss: 1.6733 - val_accuracy: 0.4130
# Epoch 4/50
# 211/211 [==============================] - 2s 8ms/step - loss: 0.3577 - accuracy: 0.9533 - val_loss: 1.8860 - val_accuracy: 0.3880
# Epoch 5/50
# 211/211 [==============================] - 2s 8ms/step - loss: 0.2885 - accuracy: 0.9610 - val_loss: 1.8717 - val_accuracy: 0.4217
# Epoch 6/50
# 211/211 [==============================] - 2s 8ms/step - loss: 0.2404 - accuracy: 0.9673 - val_loss: 2.0608 - val_accuracy: 0.3859
# Epoch 7/50
# 211/211 [==============================] - 2s 8ms/step - loss: 0.2053 - accuracy: 0.9711 - val_loss: 2.3320 - val_accuracy: 0.3565
# Epoch 8/50
# 211/211 [==============================] - 2s 7ms/step - loss: 0.1772 - accuracy: 0.9752 - val_loss: 2.2270 - val_accuracy: 0.3924
# Epoch 9/50
# 211/211 [==============================] - 2s 8ms/step - loss: 0.1582 - accuracy: 0.9780 - val_loss: 2.2405 - val_accuracy: 0.3783
# Epoch 10/50
# 211/211 [==============================] - 2s 7ms/step - loss: 0.1417 - accuracy: 0.9802 - val_loss: 2.4119 - val_accuracy: 0.3674
# Epoch 11/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1283 - accuracy: 0.9833 - val_loss: 2.4703 - val_accuracy: 0.3511
# Epoch 12/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1189 - accuracy: 0.9830 - val_loss: 2.4095 - val_accuracy: 0.3837
# Epoch 13/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.1075 - accuracy: 0.9859 - val_loss: 2.4635 - val_accuracy: 0.3761
# Epoch 14/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0997 - accuracy: 0.9869 - val_loss: 2.5610 - val_accuracy: 0.3598
# Epoch 15/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0923 - accuracy: 0.9874 - val_loss: 2.6394 - val_accuracy: 0.3565
# Epoch 16/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0887 - accuracy: 0.9871 - val_loss: 2.7608 - val_accuracy: 0.3413
# Epoch 17/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0816 - accuracy: 0.9893 - val_loss: 2.6389 - val_accuracy: 0.3565
# Epoch 18/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0764 - accuracy: 0.9893 - val_loss: 2.9025 - val_accuracy: 0.3370
# Epoch 19/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0725 - accuracy: 0.9900 - val_loss: 2.6157 - val_accuracy: 0.3685
# Epoch 20/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0691 - accuracy: 0.9908 - val_loss: 3.0533 - val_accuracy: 0.3217
# Epoch 21/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0664 - accuracy: 0.9909 - val_loss: 2.7193 - val_accuracy: 0.3587
# Epoch 22/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0622 - accuracy: 0.9915 - val_loss: 2.8600 - val_accuracy: 0.3533
# Epoch 23/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0605 - accuracy: 0.9912 - val_loss: 2.9665 - val_accuracy: 0.3391
# Epoch 24/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0569 - accuracy: 0.9915 - val_loss: 3.0774 - val_accuracy: 0.3326
# Epoch 25/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0546 - accuracy: 0.9920 - val_loss: 3.1888 - val_accuracy: 0.3239
# Epoch 26/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0523 - accuracy: 0.9929 - val_loss: 3.0016 - val_accuracy: 0.3424
# Epoch 27/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0495 - accuracy: 0.9935 - val_loss: 3.2142 - val_accuracy: 0.3261
# Epoch 28/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0477 - accuracy: 0.9930 - val_loss: 2.9937 - val_accuracy: 0.3435
# Epoch 29/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0458 - accuracy: 0.9936 - val_loss: 3.1456 - val_accuracy: 0.3359
# Epoch 30/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0446 - accuracy: 0.9932 - val_loss: 3.1130 - val_accuracy: 0.3402
# Epoch 31/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0426 - accuracy: 0.9942 - val_loss: 3.2037 - val_accuracy: 0.3348
# Epoch 32/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0411 - accuracy: 0.9943 - val_loss: 3.0947 - val_accuracy: 0.3424
# Epoch 33/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0402 - accuracy: 0.9939 - val_loss: 3.2512 - val_accuracy: 0.3326
# Epoch 34/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0384 - accuracy: 0.9942 - val_loss: 3.2782 - val_accuracy: 0.3326
# Epoch 35/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0376 - accuracy: 0.9942 - val_loss: 3.1503 - val_accuracy: 0.3424
# Epoch 36/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0361 - accuracy: 0.9954 - val_loss: 3.2296 - val_accuracy: 0.3391
# Epoch 37/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0349 - accuracy: 0.9951 - val_loss: 3.4803 - val_accuracy: 0.3196
# Epoch 38/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0339 - accuracy: 0.9954 - val_loss: 3.5138 - val_accuracy: 0.3239
# Epoch 39/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0324 - accuracy: 0.9949 - val_loss: 3.2377 - val_accuracy: 0.3435
# Epoch 40/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0314 - accuracy: 0.9957 - val_loss: 3.3436 - val_accuracy: 0.3326
# Epoch 41/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0304 - accuracy: 0.9955 - val_loss: 3.4012 - val_accuracy: 0.3315
# Epoch 42/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0296 - accuracy: 0.9960 - val_loss: 3.5578 - val_accuracy: 0.3207
# Epoch 43/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0287 - accuracy: 0.9963 - val_loss: 3.5053 - val_accuracy: 0.3283
# Epoch 44/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0283 - accuracy: 0.9966 - val_loss: 3.4477 - val_accuracy: 0.3304
# Epoch 45/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0272 - accuracy: 0.9960 - val_loss: 3.4607 - val_accuracy: 0.3293
# Epoch 46/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0269 - accuracy: 0.9961 - val_loss: 3.4143 - val_accuracy: 0.3359
# Epoch 47/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0261 - accuracy: 0.9967 - val_loss: 3.4227 - val_accuracy: 0.3337
# Epoch 48/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0254 - accuracy: 0.9973 - val_loss: 3.4300 - val_accuracy: 0.3370
# Epoch 49/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0245 - accuracy: 0.9970 - val_loss: 3.4601 - val_accuracy: 0.3359
# Epoch 50/50
# 211/211 [==============================] - 1s 5ms/step - loss: 0.0241 - accuracy: 0.9973 - val_loss: 3.6620 - val_accuracy: 0.3228

# %%
# specify the network
cnn = Sequential()
cnn.add(Conv2D(64, (3, 3), input_shape=(64,64,3)))
cnn.add(Activation('relu'))
cnn.add(MaxPooling2D(pool_size=(2, 2)))
cnn.add(Flatten()) 
cnn.add(Dense(units = 128, activation = 'relu'))
cnn.add(Dense(units = 4, activation = 'softmax'))
# compile the network
cnn.compile(loss='categorical_crossentropy',
              optimizer = optimizers.SGD(learning_rate=1e-3, momentum=0.95),
              metrics = ['accuracy'])

# %%
history = cnn.fit(train_data, train_labels, epochs = 100, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
plot_acc(history)
# Out:
# Epoch 1/100
# 211/211 [==============================] - 10s 16ms/step - loss: 0.7842 - accuracy: 0.6805 - val_loss: 2.9803 - val_accuracy: 0.3348
# Epoch 2/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.2117 - accuracy: 0.9407 - val_loss: 3.4907 - val_accuracy: 0.3424
# Epoch 3/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.1269 - accuracy: 0.9656 - val_loss: 3.4227 - val_accuracy: 0.3424
# Epoch 4/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0743 - accuracy: 0.9799 - val_loss: 4.8863 - val_accuracy: 0.2924
# Epoch 5/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0581 - accuracy: 0.9839 - val_loss: 4.4581 - val_accuracy: 0.3120
# Epoch 6/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0392 - accuracy: 0.9915 - val_loss: 3.6434 - val_accuracy: 0.3620
# Epoch 7/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0356 - accuracy: 0.9894 - val_loss: 3.9127 - val_accuracy: 0.3446
# Epoch 8/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0277 - accuracy: 0.9939 - val_loss: 5.5425 - val_accuracy: 0.2826
# Epoch 9/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0233 - accuracy: 0.9948 - val_loss: 5.9380 - val_accuracy: 0.2859
# Epoch 10/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0132 - accuracy: 0.9973 - val_loss: 5.6755 - val_accuracy: 0.2957
# Epoch 11/100
# 211/211 [==============================] - 4s 19ms/step - loss: 0.0093 - accuracy: 0.9990 - val_loss: 5.6575 - val_accuracy: 0.3022
# Epoch 12/100
# 211/211 [==============================] - 4s 18ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 5.9262 - val_accuracy: 0.3011
# Epoch 13/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0072 - accuracy: 0.9991 - val_loss: 4.7863 - val_accuracy: 0.3359
# Epoch 14/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0050 - accuracy: 0.9996 - val_loss: 6.6988 - val_accuracy: 0.2935
# Epoch 15/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0047 - accuracy: 0.9996 - val_loss: 5.8514 - val_accuracy: 0.3196
# Epoch 16/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 6.7189 - val_accuracy: 0.3011
# Epoch 17/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0037 - accuracy: 0.9996 - val_loss: 5.6405 - val_accuracy: 0.3337
# Epoch 18/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 5.0237 - val_accuracy: 0.3413
# Epoch 19/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 5.7847 - val_accuracy: 0.3283
# Epoch 20/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 5.9071 - val_accuracy: 0.3228
# Epoch 21/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 6.2847 - val_accuracy: 0.3217
# Epoch 22/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 6.2690 - val_accuracy: 0.3250
# Epoch 23/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.7664 - val_accuracy: 0.3337
# Epoch 24/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 6.3118 - val_accuracy: 0.3228
# Epoch 25/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 6.1272 - val_accuracy: 0.3293
# Epoch 26/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 6.5041 - val_accuracy: 0.3250
# Epoch 27/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 6.4971 - val_accuracy: 0.3272
# Epoch 28/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.3540 - val_accuracy: 0.3293
# Epoch 29/100
# 211/211 [==============================] - 3s 14ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.5607 - val_accuracy: 0.3261
# Epoch 30/100
# 211/211 [==============================] - 3s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 6.3502 - val_accuracy: 0.3293
# Epoch 31/100
# 211/211 [==============================] - 3s 13ms/step - loss: 9.5743e-04 - accuracy: 1.0000 - val_loss: 6.5919 - val_accuracy: 0.3250
# Epoch 32/100
# 211/211 [==============================] - 3s 13ms/step - loss: 9.5201e-04 - accuracy: 1.0000 - val_loss: 6.5788 - val_accuracy: 0.3304
# Epoch 33/100
# 211/211 [==============================] - 3s 13ms/step - loss: 9.1328e-04 - accuracy: 1.0000 - val_loss: 6.8849 - val_accuracy: 0.3239
# Epoch 34/100
# 211/211 [==============================] - 3s 14ms/step - loss: 8.4830e-04 - accuracy: 1.0000 - val_loss: 6.7627 - val_accuracy: 0.3283
# Epoch 35/100
# 211/211 [==============================] - 3s 13ms/step - loss: 7.8390e-04 - accuracy: 1.0000 - val_loss: 7.0301 - val_accuracy: 0.3239
# Epoch 36/100
# 211/211 [==============================] - 3s 13ms/step - loss: 7.9344e-04 - accuracy: 1.0000 - val_loss: 6.8840 - val_accuracy: 0.3261
# Epoch 37/100
# 211/211 [==============================] - 3s 13ms/step - loss: 7.6468e-04 - accuracy: 1.0000 - val_loss: 6.9455 - val_accuracy: 0.3272
# Epoch 38/100
# 211/211 [==============================] - 3s 13ms/step - loss: 7.0155e-04 - accuracy: 1.0000 - val_loss: 7.2000 - val_accuracy: 0.3207
# Epoch 39/100
# 211/211 [==============================] - 3s 14ms/step - loss: 6.8651e-04 - accuracy: 1.0000 - val_loss: 6.6583 - val_accuracy: 0.3348
# Epoch 40/100
# 211/211 [==============================] - 3s 13ms/step - loss: 6.5106e-04 - accuracy: 1.0000 - val_loss: 6.9425 - val_accuracy: 0.3283
# Epoch 41/100
# 211/211 [==============================] - 3s 13ms/step - loss: 6.2673e-04 - accuracy: 1.0000 - val_loss: 7.1430 - val_accuracy: 0.3250
# Epoch 42/100
# 211/211 [==============================] - 3s 13ms/step - loss: 6.0217e-04 - accuracy: 1.0000 - val_loss: 7.2984 - val_accuracy: 0.3196
# Epoch 43/100
# 211/211 [==============================] - 3s 14ms/step - loss: 6.0595e-04 - accuracy: 1.0000 - val_loss: 6.9518 - val_accuracy: 0.3293
# Epoch 44/100
# 211/211 [==============================] - 3s 13ms/step - loss: 5.7492e-04 - accuracy: 1.0000 - val_loss: 7.1505 - val_accuracy: 0.3261
# Epoch 45/100
# 211/211 [==============================] - 3s 13ms/step - loss: 5.3522e-04 - accuracy: 1.0000 - val_loss: 6.9085 - val_accuracy: 0.3337
# Epoch 46/100
# 211/211 [==============================] - 3s 13ms/step - loss: 5.3649e-04 - accuracy: 1.0000 - val_loss: 7.2824 - val_accuracy: 0.3261
# Epoch 47/100
# 211/211 [==============================] - 3s 13ms/step - loss: 5.2526e-04 - accuracy: 1.0000 - val_loss: 6.9797 - val_accuracy: 0.3283
# Epoch 48/100
# 211/211 [==============================] - 3s 14ms/step - loss: 5.0315e-04 - accuracy: 1.0000 - val_loss: 7.1213 - val_accuracy: 0.3272
# Epoch 49/100
# 211/211 [==============================] - 3s 14ms/step - loss: 4.9626e-04 - accuracy: 1.0000 - val_loss: 7.2961 - val_accuracy: 0.3293
# Epoch 50/100
# 211/211 [==============================] - 3s 14ms/step - loss: 4.8623e-04 - accuracy: 1.0000 - val_loss: 7.0680 - val_accuracy: 0.3315
# Epoch 51/100
# 211/211 [==============================] - 3s 13ms/step - loss: 4.6310e-04 - accuracy: 1.0000 - val_loss: 7.6317 - val_accuracy: 0.3207
# Epoch 52/100
# 211/211 [==============================] - 3s 14ms/step - loss: 4.5737e-04 - accuracy: 1.0000 - val_loss: 7.2111 - val_accuracy: 0.3272
# Epoch 53/100
# 211/211 [==============================] - 3s 14ms/step - loss: 4.2878e-04 - accuracy: 1.0000 - val_loss: 7.1340 - val_accuracy: 0.3326
# Epoch 54/100
# 211/211 [==============================] - 3s 13ms/step - loss: 4.1703e-04 - accuracy: 1.0000 - val_loss: 7.0250 - val_accuracy: 0.3337
# Epoch 55/100
# 211/211 [==============================] - 3s 14ms/step - loss: 4.2020e-04 - accuracy: 1.0000 - val_loss: 7.5206 - val_accuracy: 0.3250
# Epoch 56/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.9907e-04 - accuracy: 1.0000 - val_loss: 7.2563 - val_accuracy: 0.3283
# Epoch 57/100
# 211/211 [==============================] - 3s 14ms/step - loss: 3.9533e-04 - accuracy: 1.0000 - val_loss: 7.3517 - val_accuracy: 0.3304
# Epoch 58/100
# 211/211 [==============================] - 3s 13ms/step - loss: 4.0518e-04 - accuracy: 1.0000 - val_loss: 7.2667 - val_accuracy: 0.3261
# Epoch 59/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.7140e-04 - accuracy: 1.0000 - val_loss: 7.4529 - val_accuracy: 0.3272
# Epoch 60/100
# 211/211 [==============================] - 3s 14ms/step - loss: 3.7884e-04 - accuracy: 1.0000 - val_loss: 7.4805 - val_accuracy: 0.3261
# Epoch 61/100
# 211/211 [==============================] - 3s 14ms/step - loss: 3.5989e-04 - accuracy: 1.0000 - val_loss: 7.5395 - val_accuracy: 0.3261
# Epoch 62/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.5546e-04 - accuracy: 1.0000 - val_loss: 7.7006 - val_accuracy: 0.3239
# Epoch 63/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.6011e-04 - accuracy: 1.0000 - val_loss: 7.5692 - val_accuracy: 0.3272
# Epoch 64/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.3572e-04 - accuracy: 1.0000 - val_loss: 7.4388 - val_accuracy: 0.3293
# Epoch 65/100
# 211/211 [==============================] - 3s 14ms/step - loss: 3.2997e-04 - accuracy: 1.0000 - val_loss: 7.6024 - val_accuracy: 0.3261
# Epoch 66/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.2849e-04 - accuracy: 1.0000 - val_loss: 7.4454 - val_accuracy: 0.3315
# Epoch 67/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.2149e-04 - accuracy: 1.0000 - val_loss: 7.6243 - val_accuracy: 0.3293
# Epoch 68/100
# 211/211 [==============================] - 3s 14ms/step - loss: 3.1344e-04 - accuracy: 1.0000 - val_loss: 7.6518 - val_accuracy: 0.3250
# Epoch 69/100
# 211/211 [==============================] - 3s 13ms/step - loss: 3.0779e-04 - accuracy: 1.0000 - val_loss: 7.7605 - val_accuracy: 0.3261
# Epoch 70/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.9705e-04 - accuracy: 1.0000 - val_loss: 8.0125 - val_accuracy: 0.3196
# Epoch 71/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.9474e-04 - accuracy: 1.0000 - val_loss: 7.7223 - val_accuracy: 0.3261
# Epoch 72/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.9176e-04 - accuracy: 1.0000 - val_loss: 7.6626 - val_accuracy: 0.3272
# Epoch 73/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.8981e-04 - accuracy: 1.0000 - val_loss: 7.7238 - val_accuracy: 0.3261
# Epoch 74/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.8055e-04 - accuracy: 1.0000 - val_loss: 7.6138 - val_accuracy: 0.3283
# Epoch 75/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.7696e-04 - accuracy: 1.0000 - val_loss: 7.6876 - val_accuracy: 0.3261
# Epoch 76/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.6813e-04 - accuracy: 1.0000 - val_loss: 7.6604 - val_accuracy: 0.3283
# Epoch 77/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.6120e-04 - accuracy: 1.0000 - val_loss: 7.6768 - val_accuracy: 0.3272
# Epoch 78/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.5780e-04 - accuracy: 1.0000 - val_loss: 7.6335 - val_accuracy: 0.3293
# Epoch 79/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.5442e-04 - accuracy: 1.0000 - val_loss: 7.9060 - val_accuracy: 0.3261
# Epoch 80/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.5324e-04 - accuracy: 1.0000 - val_loss: 7.8444 - val_accuracy: 0.3250
# Epoch 81/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.5201e-04 - accuracy: 1.0000 - val_loss: 7.7127 - val_accuracy: 0.3283
# Epoch 82/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.4386e-04 - accuracy: 1.0000 - val_loss: 7.7675 - val_accuracy: 0.3250
# Epoch 83/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.3932e-04 - accuracy: 1.0000 - val_loss: 7.8126 - val_accuracy: 0.3261
# Epoch 84/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.3375e-04 - accuracy: 1.0000 - val_loss: 7.7338 - val_accuracy: 0.3283
# Epoch 85/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.3229e-04 - accuracy: 1.0000 - val_loss: 7.8392 - val_accuracy: 0.3250
# Epoch 86/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.2779e-04 - accuracy: 1.0000 - val_loss: 7.9221 - val_accuracy: 0.3261
# Epoch 87/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.2653e-04 - accuracy: 1.0000 - val_loss: 7.8488 - val_accuracy: 0.3239
# Epoch 88/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.1892e-04 - accuracy: 1.0000 - val_loss: 7.9652 - val_accuracy: 0.3272
# Epoch 89/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.1928e-04 - accuracy: 1.0000 - val_loss: 7.7799 - val_accuracy: 0.3304
# Epoch 90/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.1780e-04 - accuracy: 1.0000 - val_loss: 8.0252 - val_accuracy: 0.3283
# Epoch 91/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.1338e-04 - accuracy: 1.0000 - val_loss: 8.0179 - val_accuracy: 0.3272
# Epoch 92/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.0931e-04 - accuracy: 1.0000 - val_loss: 7.9502 - val_accuracy: 0.3261
# Epoch 93/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.0524e-04 - accuracy: 1.0000 - val_loss: 7.8935 - val_accuracy: 0.3272
# Epoch 94/100
# 211/211 [==============================] - 3s 13ms/step - loss: 2.0345e-04 - accuracy: 1.0000 - val_loss: 8.1006 - val_accuracy: 0.3272
# Epoch 95/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.0172e-04 - accuracy: 1.0000 - val_loss: 7.7446 - val_accuracy: 0.3326
# Epoch 96/100
# 211/211 [==============================] - 3s 14ms/step - loss: 2.0391e-04 - accuracy: 1.0000 - val_loss: 8.0157 - val_accuracy: 0.3272
# Epoch 97/100
# 211/211 [==============================] - 3s 13ms/step - loss: 1.9831e-04 - accuracy: 1.0000 - val_loss: 7.9774 - val_accuracy: 0.3261
# Epoch 98/100
# 211/211 [==============================] - 3s 14ms/step - loss: 1.9353e-04 - accuracy: 1.0000 - val_loss: 7.9599 - val_accuracy: 0.3272
# Epoch 99/100
# 211/211 [==============================] - 3s 13ms/step - loss: 1.9313e-04 - accuracy: 1.0000 - val_loss: 8.0403 - val_accuracy: 0.3250
# Epoch 100/100
# 211/211 [==============================] - 3s 13ms/step - loss: 1.8726e-04 - accuracy: 1.0000 - val_loss: 8.1543 - val_accuracy: 0.3272

# %% [markdown]
# Afterwards, see if you can get 85% accuracy with your model!

# %%
transfer = TransferClassifier(name = 'VGG16')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# 58900480/58889256 [==============================] - 0s 0us/step
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
from tensorflow.keras.applications.vgg16 import VGG16

# %%
# load the vgg network that is an 'expert' at 'imagenet' but do not include the FC layers
vgg_expert = VGG16(weights = 'imagenet', include_top = False, input_shape = (64, 64, 3))

# %%
vgg_model = Sequential()
vgg_model.add(vgg_expert)

# %%
# add the extra layers here
vgg_model.add(GlobalAveragePooling2D())
vgg_model.add(Dense(1024, activation = 'relu'))
vgg_model.add(Dropout(0.3))
vgg_model.add(Dense(512, activation = 'relu'))
vgg_model.add(Dropout(0.3))
vgg_model.add(Dense(4, activation = 'sigmoid'))

# %%
# compile our model
vgg_model.compile(loss = 'categorical_crossentropy',
                  optimizer = optimizers.SGD(learning_rate = 1e-4, momentum = 0.95),
                  metrics = ['accuracy'])

# %%
history = vgg_model.fit(train_data, train_labels, epochs = 50, validation_data = (test_data, test_labels), shuffle = True, callbacks = [monitor])
plot_acc(history)
# Out:
# Epoch 1/50
# 211/211 [==============================] - 28s 118ms/step - loss: 0.9503 - accuracy: 0.5675 - val_loss: 1.4739 - val_accuracy: 0.4902
# Epoch 2/50
# 211/211 [==============================] - 23s 110ms/step - loss: 0.2201 - accuracy: 0.9283 - val_loss: 0.8797 - val_accuracy: 0.6717
# Epoch 3/50
# 211/211 [==============================] - 23s 110ms/step - loss: 0.0883 - accuracy: 0.9734 - val_loss: 0.8533 - val_accuracy: 0.7511
# Epoch 4/50
# 211/211 [==============================] - 23s 110ms/step - loss: 0.0540 - accuracy: 0.9866 - val_loss: 0.8046 - val_accuracy: 0.7804
# Epoch 5/50
# 211/211 [==============================] - 24s 112ms/step - loss: 0.0332 - accuracy: 0.9924 - val_loss: 0.8010 - val_accuracy: 0.8457
# Epoch 6/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0242 - accuracy: 0.9946 - val_loss: 1.2131 - val_accuracy: 0.7022
# Epoch 7/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0248 - accuracy: 0.9935 - val_loss: 1.0325 - val_accuracy: 0.7011
# Epoch 8/50
# 211/211 [==============================] - 23s 110ms/step - loss: 0.0152 - accuracy: 0.9967 - val_loss: 0.7702 - val_accuracy: 0.7913
# Epoch 9/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0103 - accuracy: 0.9981 - val_loss: 1.0563 - val_accuracy: 0.7674
# Epoch 10/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0146 - accuracy: 0.9955 - val_loss: 0.9321 - val_accuracy: 0.7924
# Epoch 11/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0074 - accuracy: 0.9982 - val_loss: 0.8631 - val_accuracy: 0.7989
# Epoch 12/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0068 - accuracy: 0.9982 - val_loss: 0.9885 - val_accuracy: 0.7902
# Epoch 13/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0062 - accuracy: 0.9984 - val_loss: 2.0654 - val_accuracy: 0.5946
# Epoch 14/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 1.3758 - val_accuracy: 0.7217
# Epoch 15/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0038 - accuracy: 0.9994 - val_loss: 1.3028 - val_accuracy: 0.7043
# Epoch 16/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0020 - accuracy: 0.9994 - val_loss: 1.3297 - val_accuracy: 0.7359
# Epoch 17/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0034 - accuracy: 0.9988 - val_loss: 1.1914 - val_accuracy: 0.7598
# Epoch 18/50
# 211/211 [==============================] - 23s 110ms/step - loss: 8.8416e-04 - accuracy: 0.9999 - val_loss: 1.4425 - val_accuracy: 0.7500
# Epoch 19/50
# 211/211 [==============================] - 23s 108ms/step - loss: 6.3259e-04 - accuracy: 1.0000 - val_loss: 1.4142 - val_accuracy: 0.7043
# Epoch 20/50
# 211/211 [==============================] - 23s 108ms/step - loss: 5.7010e-04 - accuracy: 1.0000 - val_loss: 1.4985 - val_accuracy: 0.6935
# Epoch 21/50
# 211/211 [==============================] - 23s 110ms/step - loss: 1.8618e-04 - accuracy: 1.0000 - val_loss: 1.2924 - val_accuracy: 0.7652
# Epoch 22/50
# 211/211 [==============================] - 23s 108ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 1.2501 - val_accuracy: 0.7380
# Epoch 23/50
# 211/211 [==============================] - 23s 108ms/step - loss: 9.0851e-04 - accuracy: 1.0000 - val_loss: 1.2122 - val_accuracy: 0.7891
# Epoch 24/50
# 211/211 [==============================] - 23s 108ms/step - loss: 3.8945e-04 - accuracy: 1.0000 - val_loss: 1.2682 - val_accuracy: 0.7467
# Epoch 25/50
# 211/211 [==============================] - 23s 108ms/step - loss: 8.7386e-04 - accuracy: 0.9997 - val_loss: 1.3390 - val_accuracy: 0.7413
# Epoch 26/50
# 211/211 [==============================] - 23s 108ms/step - loss: 2.6864e-04 - accuracy: 1.0000 - val_loss: 1.6359 - val_accuracy: 0.6772
# Epoch 27/50
# 211/211 [==============================] - 23s 108ms/step - loss: 2.9005e-04 - accuracy: 1.0000 - val_loss: 1.4241 - val_accuracy: 0.7261
# Epoch 28/50
# 211/211 [==============================] - 23s 108ms/step - loss: 5.5185e-04 - accuracy: 0.9999 - val_loss: 1.2633 - val_accuracy: 0.7326
# Epoch 29/50
# 211/211 [==============================] - 23s 108ms/step - loss: 3.9111e-04 - accuracy: 0.9999 - val_loss: 1.2015 - val_accuracy: 0.7620
# Epoch 30/50
# 211/211 [==============================] - 23s 108ms/step - loss: 2.2775e-04 - accuracy: 1.0000 - val_loss: 1.3889 - val_accuracy: 0.7370
# Epoch 31/50
# 211/211 [==============================] - 23s 108ms/step - loss: 1.2518e-04 - accuracy: 1.0000 - val_loss: 1.3162 - val_accuracy: 0.7511
# Epoch 32/50
# 211/211 [==============================] - 23s 108ms/step - loss: 9.0497e-05 - accuracy: 1.0000 - val_loss: 1.2762 - val_accuracy: 0.7620
# Epoch 33/50
# 211/211 [==============================] - 23s 108ms/step - loss: 9.7090e-05 - accuracy: 1.0000 - val_loss: 1.4138 - val_accuracy: 0.7424
# Epoch 34/50
# 211/211 [==============================] - 23s 108ms/step - loss: 4.6596e-04 - accuracy: 1.0000 - val_loss: 1.5472 - val_accuracy: 0.6957
# Epoch 35/50
# 211/211 [==============================] - 23s 108ms/step - loss: 1.7314e-04 - accuracy: 1.0000 - val_loss: 1.4730 - val_accuracy: 0.7109
# Epoch 36/50
# 211/211 [==============================] - 23s 110ms/step - loss: 9.3269e-05 - accuracy: 1.0000 - val_loss: 1.3793 - val_accuracy: 0.7467
# Epoch 37/50
# 211/211 [==============================] - 23s 108ms/step - loss: 1.0424e-04 - accuracy: 1.0000 - val_loss: 1.3903 - val_accuracy: 0.7446
# Epoch 38/50
# 211/211 [==============================] - 23s 108ms/step - loss: 1.0848e-04 - accuracy: 1.0000 - val_loss: 1.6149 - val_accuracy: 0.7109
# Epoch 39/50
# 211/211 [==============================] - 23s 108ms/step - loss: 1.1046e-04 - accuracy: 1.0000 - val_loss: 1.6651 - val_accuracy: 0.7196
# Epoch 40/50
# 211/211 [==============================] - 23s 108ms/step - loss: 8.5693e-05 - accuracy: 1.0000 - val_loss: 1.3826 - val_accuracy: 0.7663
# Epoch 41/50
# 211/211 [==============================] - 23s 108ms/step - loss: 5.0753e-05 - accuracy: 1.0000 - val_loss: 1.3939 - val_accuracy: 0.7652
# Epoch 42/50
# 211/211 [==============================] - 23s 108ms/step - loss: 5.7712e-05 - accuracy: 1.0000 - val_loss: 1.4127 - val_accuracy: 0.7707
# Epoch 43/50
# 211/211 [==============================] - 23s 110ms/step - loss: 8.9518e-05 - accuracy: 1.0000 - val_loss: 1.6065 - val_accuracy: 0.7185
# Epoch 44/50
# 211/211 [==============================] - 23s 108ms/step - loss: 7.9520e-05 - accuracy: 1.0000 - val_loss: 1.4832 - val_accuracy: 0.7489
# Epoch 45/50
# 211/211 [==============================] - 23s 108ms/step - loss: 4.2291e-05 - accuracy: 1.0000 - val_loss: 1.4103 - val_accuracy: 0.7663
# Epoch 46/50
# 211/211 [==============================] - 23s 108ms/step - loss: 5.0176e-04 - accuracy: 0.9997 - val_loss: 2.4036 - val_accuracy: 0.6228
# Epoch 47/50
# 211/211 [==============================] - 23s 109ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 1.2785 - val_accuracy: 0.7609
# Epoch 48/50
# 211/211 [==============================] - 23s 109ms/step - loss: 1.8845e-04 - accuracy: 1.0000 - val_loss: 1.3304 - val_accuracy: 0.7391
# Epoch 49/50
# 211/211 [==============================] - 23s 109ms/step - loss: 1.2772e-04 - accuracy: 1.0000 - val_loss: 1.4621 - val_accuracy: 0.7217
# Epoch 50/50
# 211/211 [==============================] - 23s 109ms/step - loss: 1.6717e-04 - accuracy: 1.0000 - val_loss: 1.4722 - val_accuracy: 0.7370
